# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\Ai course MEC\\archive\\processes2.csv")

# %%
df
# Out:
#       Unnamed: 0     name  year  selling_price  km_driven    fuel seller_type  \
# 0              0   Maruti  2014         450000     145500  Diesel  Individual
# 1              2  Hyundai  2010         225000     127000  Diesel  Individual
# 2              4  Hyundai  2017         440000      45000  Petrol  Individual
# 3              7   Toyota  2011         350000      90000  Diesel  Individual
# 4              8     Ford  2013         200000     169000  Diesel  Individual
# ...          ...      ...   ...            ...        ...     ...         ...
# 2090        6245   Maruti  2017         425000      12000  Petrol  Individual
# 2091        6246   Toyota  2014         425000      50000  Diesel  Individual
# 2092        6249   Maruti  2011         200000      73000  Petrol  Individual
# 2093        6253   Maruti  2017         360000      80000  Petrol  Individual
# 2094        6256  Hyundai  2014         475000      80000  Diesel  Individual
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          2095 non-null   int64
#  1   name                2095 non-null   object
#  2   year                2095 non-null   int64
#  3   selling_price       2095 non-null   int64
#  4   km_driven           2095 non-null   int64
#  5   fuel                2095 non-null   object
#  6   seller_type         2095 non-null   object
#  7   transmission        2095 non-null   object
#  8   owner               2095 non-null   object
#  9   seats               2095 non-null   int64
#  10  max_power (in bph)  2095 non-null   float64
#  11  Mileage Unit        2095 non-null   object
#  12  Mileage             2095 non-null   float64
#  13  Engine (CC)         2095 non-null   int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 229.3+ KB

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#               year  selling_price      km_driven        seats  \
# count  2095.000000   2.095000e+03    2095.000000  2095.000000
# mean   2014.052506   4.272799e+05   67413.593795     5.096897
# std       3.273451   2.326698e+05   41580.846333     0.457000
# min    2000.000000   4.595700e+04    1000.000000     4.000000
# 25%    2012.000000   2.500000e+05   35000.000000     5.000000
# 50%    2014.000000   3.900000e+05   60000.000000     5.000000
# 75%    2017.000000   5.555000e+05   90000.000000     5.000000
# max    2020.000000   1.594000e+06  270000.000000     8.000000
#
#        max_power (in bph)      Mileage  Engine (CC)
# count         2095.000000  2095.000000  2095.000000
# mean            77.410427    21.397928  1205.078282
# std             19.884938     1.209234   245.058696
# min             35.000000    19.600000   624.000000
# 25%             67.040000    20.360000   998.000000
# 50%             74.000000    21.100000  1248.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                  0
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# seats                 0
# max_power (in bph)    0
# Mileage Unit          0
# Mileage               0
# Engine (CC)           0
# dtype: int64

# %%
#sns.boxplot(df['Engine (CC)'])

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'seats', 'max_power (in bph)', 'Mileage Unit',
#        'Mileage', 'Engine (CC)'],
#       dtype='object')

# %%
num_corr= df[['year', 'selling_price', 'km_driven','seats', 'max_power (in bph)','Mileage', 'Engine (CC)']]

# %%
corr = num_corr.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, linewidths=0.5, fmt='.2f')
plt.show()

# %%
df['selling_price'].plot(kind='hist',bins=20, edgecolor='black')
plt.show()

# %%
df['Mileage'].plot(kind='hist', bins=20, edgecolor='black')
plt.show()

# %%
df['km_driven'].plot(kind='hist', bins=20, edgecolor='black')
plt.show()

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG', 'LPG'], dtype=object)

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
df['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['seats'].unique()
# Out:
# array([5, 7, 8, 4], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'seats', 'max_power (in bph)', 'Mileage Unit',
#        'Mileage', 'Engine (CC)'],
#       dtype='object')

# %%
x= df[['year','km_driven', 'seats', 'max_power (in bph)','Mileage', 'Engine (CC)']]

y=df['selling_price']

# %%
x_train,x_test, y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=50)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_model.predict(x_test)

# %%
linear_model.score(x_test, y_test)
# Out:
# 0.7365426955580239

# %%
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison)
# Out:
#        Actual      Predicted
# 905    570000  573184.882194
# 1314   400000  399115.903597
# 275    310000  323024.626819
# 347    500000  553987.290159
# 1706  1000000  755797.266583
# ...       ...            ...
# 1623   650000  634205.079435
# 1308   220000  159887.418555
# 1874   440000  500744.234755
# 249    175000  289847.160773
# 1875   200000  274992.524398
#
# [419 rows x 2 columns]

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_y_pred = rf_model.predict(x_test)

# %%
rf_model.score(x_test, y_test)
# Out:
# 0.8954800529342637

# %%
comparison_rf = pd.DataFrame({'Actual': y_test, 'Predicted': rf_y_pred})
print(comparison_rf)
# Out:
#        Actual      Predicted
# 905    570000  612460.000000
# 1314   400000  361113.193333
# 275    310000  253814.874333
# 347    500000  487709.985000
# 1706  1000000  982713.333333
# ...       ...            ...
# 1623   650000  612621.354643
# 1308   220000  240849.930000
# 1874   440000  423200.000000
# 249    175000  195758.273810
# 1875   200000  187053.333333
#
# [419 rows x 2 columns]
